# %%
import pandas as pd
#import geopandas as gpd

import datetime as dt

# %%
data=pd.read_csv("static/data/new_data.csv")
data
# Out:
#       Unnamed: 0         ID    Source    TMC  Severity        Start_Time  \
# 0        3429348  A-3436071      Bing    NaN         2  12/29/2020 16:15
# 1        3804311  A-3811172      Bing    NaN         2  10/19/2019 18:46
# 2        3380099  A-3386170      Bing    NaN         2   11/21/2020 8:43
# 3        3003577  A-3004433      Bing    NaN         2  11/20/2020 13:18
# 4        1218502  A-1218605  MapQuest  201.0         3   9/16/2019 18:56
# ...          ...        ...       ...    ...       ...               ...
# 4995     3530355  A-3537153      Bing    NaN         1    6/8/2020 15:30
# 4996     3115346  A-3117788      Bing    NaN         2    12/9/2020 5:35
# 4997      964731   A-964825  MapQuest  201.0         2   2/21/2020 17:07
# 4998      935077   A-935170  MapQuest  201.0         3     2/5/2020 8:02
# 4999     3292761  A-3297731      Bing    NaN         2   10/15/2020 3:02
#
#               End_Time        lat        long    End_Lat  ...  Roundabout  \
# ...

# %%
#create summery from new data(state,accident counts,sevierity average)

# %%
#create table in database
#load summery data in table

# %%
#load us_states.geojson file
# convert to dictionary
#loop through summary data from table
#dictionay data. fearture.properties.name=

# %%
def getStatename(abb):
    if abb=="AL":return("Alabama")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Source', 'TMC', 'Severity', 'Start_Time',
#        'End_Time', 'lat', 'long', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data['State'].describe()

# %%
new=data['Start_Time'].str.split(" ",n=1,expand=True)
data['date']=new[0]
data
# Out:
#       Unnamed: 0         ID    Source    TMC  Severity        Start_Time  \
# 0        3429348  A-3436071      Bing    NaN         2  12/29/2020 16:15
# 1        3804311  A-3811172      Bing    NaN         2  10/19/2019 18:46
# 2        3380099  A-3386170      Bing    NaN         2   11/21/2020 8:43
# 3        3003577  A-3004433      Bing    NaN         2  11/20/2020 13:18
# 4        1218502  A-1218605  MapQuest  201.0         3   9/16/2019 18:56
# ...          ...        ...       ...    ...       ...               ...
# 4995     3530355  A-3537153      Bing    NaN         1    6/8/2020 15:30
# 4996     3115346  A-3117788      Bing    NaN         2    12/9/2020 5:35
# 4997      964731   A-964825  MapQuest  201.0         2   2/21/2020 17:07
# 4998      935077   A-935170  MapQuest  201.0         3     2/5/2020 8:02
# 4999     3292761  A-3297731      Bing    NaN         2   10/15/2020 3:02
#
#               End_Time        lat        long    End_Lat  ...  Station   Stop  \
# ...

# %%
day=data['date'].str.split("/",n=1,expand=True)
data['month']=day[1]
data
# Out:
#       Unnamed: 0         ID    Source    TMC  Severity        Start_Time  \
# 0        3429348  A-3436071      Bing    NaN         2  12/29/2020 16:15
# 1        3804311  A-3811172      Bing    NaN         2  10/19/2019 18:46
# 2        3380099  A-3386170      Bing    NaN         2   11/21/2020 8:43
# 3        3003577  A-3004433      Bing    NaN         2  11/20/2020 13:18
# 4        1218502  A-1218605  MapQuest  201.0         3   9/16/2019 18:56
# ...          ...        ...       ...    ...       ...               ...
# 4995     3530355  A-3537153      Bing    NaN         1    6/8/2020 15:30
# 4996     3115346  A-3117788      Bing    NaN         2    12/9/2020 5:35
# 4997      964731   A-964825  MapQuest  201.0         2   2/21/2020 17:07
# 4998      935077   A-935170  MapQuest  201.0         3     2/5/2020 8:02
# 4999     3292761  A-3297731      Bing    NaN         2   10/15/2020 3:02
#
#               End_Time        lat        long    End_Lat  ...   Stop  \
# ...

# %%
year=data['month'].str.split("/",n=1,expand=True)
data['Year']=year[1]
data
# Out:
#       Unnamed: 0         ID    Source    TMC  Severity        Start_Time  \
# 0        3429348  A-3436071      Bing    NaN         2  12/29/2020 16:15
# 1        3804311  A-3811172      Bing    NaN         2  10/19/2019 18:46
# 2        3380099  A-3386170      Bing    NaN         2   11/21/2020 8:43
# 3        3003577  A-3004433      Bing    NaN         2  11/20/2020 13:18
# 4        1218502  A-1218605  MapQuest  201.0         3   9/16/2019 18:56
# ...          ...        ...       ...    ...       ...               ...
# 4995     3530355  A-3537153      Bing    NaN         1    6/8/2020 15:30
# 4996     3115346  A-3117788      Bing    NaN         2    12/9/2020 5:35
# 4997      964731   A-964825  MapQuest  201.0         2   2/21/2020 17:07
# 4998      935077   A-935170  MapQuest  201.0         3     2/5/2020 8:02
# 4999     3292761  A-3297731      Bing    NaN         2   10/15/2020 3:02
#
#               End_Time        lat        long    End_Lat  ...  \
# ...

# %%
data.describe()

# %%
avg_severity_data=data.groupby(['State'])['Severity'].mean()

# %%
data['State'].value_counts()

# %%
accident_by_year=data.groupby(['Year'])['State'].value_counts()
                              
accident_by_year
# Out:
# Year  State
# 2019  CA       493
#       TX       170
#       SC       135
#       FL       126
#       NC       114
#               ...
# 2020  RI         3
#       ND         1
#       SD         1
#       VT         1
#       WV         1
# Name: State, Length: 90, dtype: int64

# %%
data['Year'].value_counts()
# Out:
# 2020    2741
# 2019    2173
# Name: Year, dtype: int64

# %%
df=pd.DataFrame(accident_by_year)
df
# Out:
#             State
# Year State
# 2019 CA       493
#      TX       170
#      SC       135
#      FL       126
#      NC       114
# ...           ...
# 2020 RI         3
#      ND         1
#      SD         1
#      VT         1
#      WV         1
#
# [90 rows x 1 columns]

# %%
df.columns=['no_of_accidents']

# %%
df.head(60)
# Out:
#             no_of_accidents
# Year State
# 2019 CA                 493
#      TX                 170
#      SC                 135
#      FL                 126
#      NC                 114
#      NY                  94
#      OR                  89
#      AZ                  57
#      GA                  56
#      MI                  54
#      UT                  54
#      LA                  52
#      IL                  51
#      MN                  51
#      VA                  51
#      OK                  50
#      PA                  50
#      TN                  42
#      WA                  41
#      AL                  38
#      CO                  37
#      MO                  36
#      NJ                  33
#      OH                  31
#      MD                  23
#      WI                  20
#      KY                  19
#      MA                  18
#      IN                  13
#      CT                  12
#      IA                   8
# ...
